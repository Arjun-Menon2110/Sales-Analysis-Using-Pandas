# %% [markdown]
# # Sales Analysis

# %%
import pandas as pd
import os

# %% [markdown]
# ### merging 12 month of data

# %%
all_months_data = pd.DataFrame()

# Directory where the CSV files are located
folder_path = r'C:\Users\arjun\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data'

# List all CSV files in the folder
files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# Loop through each file
for i, file in enumerate(files):
    file_path = os.path.join(folder_path, file)
    
    # For all but the first file, skip the first row (header)
    if i == 0:
        df = pd.read_csv(file_path)  # First file includes the header
    else:
        df = pd.read_csv(file_path, header=0)  # Skip the header for subsequent files
    
    # Concatenate data to the all_months_data DataFrame
    all_months_data = pd.concat([all_months_data, df], ignore_index=True)

# %%
import os
import pandas as pd

# Directory where the CSV files are located
folder_path = r'C:\Users\arjun\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data'

# Create an empty DataFrame to hold the data
all_months_data = pd.DataFrame()

# List all CSV files in the folder
files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# Loop through each file
for file in files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    
    # Remove rows where all values match the first row (likely duplicate headers)
    df = df[df.columns].loc[~(df.values == df.columns.values).all(axis=1)]
    
    # Concatenate the data into the all_months_data DataFrame
    all_months_data = pd.concat([all_months_data, df], ignore_index=True)

# Save the concatenated data to a new CSV file
output_path = r'C:\Users\arjun\Downloads\all_months_data_cleaned.csv'
all_months_data.to_csv(output_path, index=False)

print(f"Cleaned data appended and saved to {output_path}")
# Out:
# Cleaned data appended and saved to C:\Users\arjun\Downloads\all_months_data_cleaned.csv

# %%
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

# %%
all_months_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
all_months_data.to_csv("all_data.csv",index=False)

# %% [markdown]
# ### Read in Updated Dataframe

# %%
all_data=pd.read_csv("all_data.csv")
all_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0  176558.0        USB-C Charging Cable               2.0       11.95
# 1       NaN                         NaN               NaN         NaN
# 2  176559.0  Bose SoundSport Headphones               1.0       99.99
# 3  176560.0                Google Phone               1.0      600.00
# 4  176560.0            Wired Headphones               1.0       11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
all_data=all_data.dropna(how='all')

df = df.drop_duplicates()

# %%
all_data.reset_index(drop=True,inplace=True)

# %%
all_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0  176558.0        USB-C Charging Cable               2.0       11.95
# 1  176559.0  Bose SoundSport Headphones               1.0       99.99
# 2  176560.0                Google Phone               1.0      600.00
# 3  176560.0            Wired Headphones               1.0       11.99
# 4  176561.0            Wired Headphones               1.0       11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
len(all_data)
# Out:
# 185950

# %%
all_data.to_csv("all_data.csv",index=False)

# %%
all_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0  176558.0        USB-C Charging Cable               2.0       11.95
# 1  176559.0  Bose SoundSport Headphones               1.0       99.99
# 2  176560.0                Google Phone               1.0      600.00
# 3  176560.0            Wired Headphones               1.0       11.99
# 4  176561.0            Wired Headphones               1.0       11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
all_data['Order ID'] = all_data['Order ID'].astype(int)
all_data['Quantity Ordered'] = all_data['Quantity Ordered'].astype(int)
all_data['Price Each'] = all_data['Price Each'].astype(float)
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])
# Out:
# C:\Users\arjun\AppData\Local\Temp\ipykernel_18032\4211705226.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  int32
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int32
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
# dtypes: datetime64[ns](1), float64(1), int32(2), object(2)
# memory usage: 7.1+ MB

# %%
print(all_data.dtypes)
# Out:
# Order ID                     int32
# Product                     object
# Quantity Ordered             int32
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# dtype: object

# %%
all_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  int32
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int32
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
# dtypes: datetime64[ns](1), float64(1), int32(2), object(2)
# memory usage: 7.1+ MB

# %%
all_data['month']=all_data['Order Date'].dt.month

# %%
all_data['sale_price']=all_data['Quantity Ordered']*all_data['Price Each']

# %%
all_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  month  sale_price
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4       23.90
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4       99.99
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4      600.00
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4       11.99
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4       11.99

# %% [markdown]
# ### Month having More Sale

# %%
mon_sale=all_data.groupby('month')['sale_price'].sum().reset_index()
mon_sale.sort_values(by='sale_price',ascending=False,inplace=True)
mon_sale
# Out:
#     month  sale_price
# 11     12  4613443.34
# 9      10  3736726.88
# 3       4  3390670.24
# 10     11  3199603.20
# 4       5  3152606.75
# 2       3  2807100.38
# 6       7  2647775.76
# 5       6  2577802.26
# 7       8  2244467.88
# 1       2  2202022.42
# 8       9  2097560.13
# 0       1  1822256.73

# %%
import matplotlib.pyplot as plt
plt.bar(mon_sale['month'], mon_sale['sale_price'])

# Set Y-axis ticks to show full numbers
plt.ticklabel_format(style='plain', axis='y')  # Prevent scientific notation

# Add labels for clarity (optional)
plt.xticks(mon_sale['month'])
plt.xlabel('Month')
plt.ylabel('Sale Price')
plt.title('Monthly Sales')

# Show the plot
plt.show()

# %% [markdown]
# ### What City Had Highest Number Of Sales

# %%
c=list(all_data['Purchase Address'])
cc=[]
for i in c:
    l=i.split(",")
    d=l[1]
    e=d.split(',')
    f=e[0]
    cc.append(f)
    
    

all_data['city']=cc
all_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#    sale_price          city
# 0       23.90        Dallas
# 1       99.99        Boston
# 2      600.00   Los Angeles
# ...

# %%
city_data=all_data.groupby('city')['sale_price'].sum().reset_index()
city_data=city_data.sort_values(by='sale_price',ascending=False)
city_data
# Out:
#              city  sale_price
# 7   San Francisco  8262203.91
# 4     Los Angeles  5452570.80
# 5   New York City  4664317.43
# 2          Boston  3661642.01
# 0         Atlanta  2795498.58
# 3          Dallas  2767975.40
# 8         Seattle  2747755.48
# 6        Portland  2320490.61
# 1          Austin  1819581.75

# %%
plt.bar(city_data['city'], city_data['sale_price'])
plt.xticks(rotation='vertical')

# Set Y-axis ticks to show full numbers
plt.ticklabel_format(style='plain', axis='y')  # Prevent scientific notation

# Add labels for clarity (optional)
plt.xticks(city_data['city'])
plt.xlabel('city')
plt.ylabel('Sale Price')
plt.title('city with highest Sales')

# Show the plot
plt.show()

# %% [markdown]
# ### What time Should we display advertisement to maximize likelihood of Buying Product

# %%
all_data['time']=all_data['Order Date'].dt.time

all_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#    sale_price          city      time
# 0       23.90        Dallas  08:46:00
# 1       99.99        Boston  22:30:00
# ...

# %%
adv_time=all_data.groupby('time')['Quantity Ordered'].sum().reset_index()
adv_time=adv_time.sort_values(by='Quantity Ordered',ascending=False)
adv_time.head()
# Out:
#           time  Quantity Ordered
# 718   11:58:00               282
# 1160  19:20:00               281
# 1176  19:36:00               275
# 1157  19:17:00               272
# 805   13:25:00               271

# %% [markdown]
# ### which product  is Frequently Brought

# %%
all_data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#    sale_price          city      time
# 0       23.90        Dallas  08:46:00
# 1       99.99        Boston  22:30:00
# ...

# %%
pf=all_data.groupby('Order ID')['Product'].agg(' | '.join).reset_index()
pf=pf[pf['Product'].str.contains('|', regex=False)]
pf=pf.drop_duplicates()

answer_final = pf.groupby('Product').agg(Count=('Product', 'count')).reset_index()
answer_final=answer_final.sort_values(by='Count',ascending=False)



answer_final.head()
# Out:
#                                     Product  Count
# 342       iPhone | Lightning Charging Cable    882
# 173     Google Phone | USB-C Charging Cable    856
# 363               iPhone | Wired Headphones    361
# 299  Vareebadd Phone | USB-C Charging Cable    312
# 191         Google Phone | Wired Headphones    303

# %%
# https://stackoverflow.com/questions/43348194/pandas-select-rows-if-id-appear-several-time
df = all_data[all_data['Order ID'].duplicated(keep=False)]

# Referenced: https://stackoverflow.com/questions/27298178/concatenate-strings-from-several-rows-using-pandas-groupby
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df2 = df[['Order ID', 'Grouped']].drop_duplicates()
# Out:
# C:\Users\arjun\AppData\Local\Temp\ipykernel_18032\3162329447.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

# %%
# Referenced: https://stackoverflow.com/questions/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary
from itertools import combinations
from collections import Counter

count = Counter()

for row in df2['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key,value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# ### What Product Sold The most And Why

# %%
sold=all_data.groupby('Product')['Quantity Ordered'].sum().reset_index()
plt.bar(sold['Product'], sold['Quantity Ordered'])
plt.xticks(rotation='vertical', size=8)
plt.show()

# %%
prices = all_data.groupby('Product')['Price Each'].mean()
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(sold['Product'], sold['Quantity Ordered'], color='g')
ax2.plot(sold['Product'], prices, color='b')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticklabels(sold['Product'], rotation='vertical', size=8)

fig.show()
# Out:
# C:\Users\arjun\AppData\Local\Temp\ipykernel_18032\2630019544.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(sold['Product'], rotation='vertical', size=8)
# C:\Users\arjun\AppData\Local\Temp\ipykernel_18032\2630019544.py:13: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
